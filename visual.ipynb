# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pickle
import torch
import matplotlib.pyplot as plt

# %%
def display_mask(mask_path):
    with open(mask_path, 'rb') as handle:
        mask = pickle.load(handle)
    plt.imshow(mask, cmap='gray')
    plt.title(f"Mask: {os.path.basename(mask_path)}")
    plt.axis('off')
    plt.show()

# %%
mask_directory = "/media/mattyb/UBUNTU 22_0/datasets/imagenet_strawberries/masks/val_test_masks/exp_val"

# %%
import pickle

# Path to the .pkl file
pkl_file_path = '/media/mattyb/UBUNTU 22_0/datasets/imagenet_strawberries/masks/val_test_masks/exp_val_img_to_fh.pkl'
val_images_folder = "/media/mattyb/UBUNTU 22_0/datasets/imagenet_strawberries/images/val/val_cl0"

# Load the dictionary from the .pkl file
with open(pkl_file_path, 'rb') as f:
    masks_paths_list = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 8
#       5 val_images_folder = "/media/mattyb/UBUNTU 22_0/datasets/imagenet_strawberries/images/val/val_cl0"
#       7 # Load the dictionary from the .pkl file
# ----> 8 with open(pkl_file_path, 'rb') as f:
#       9     masks_paths_list = pickle.load(f)
#      11 masks_paths_list
#
# File ~/miniconda3/envs/detcon-pytorch/lib/python3.9/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# ...

# %%
def display_mask(mask_path):
    with open(mask_path, 'rb') as handle:
        mask = pickle.load(handle)
    plt.imshow(mask, cmap='gray')
    plt.title(f"Mask: {os.path.basename(mask_path)}")
    plt.axis('off')
    plt.show()

display_mask(masks_paths_list[1])
